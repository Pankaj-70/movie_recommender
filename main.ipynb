# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies = movies.merge(credits, on='title')

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
import ast

def convert(text, parameter):
    L = []
    cnt = 0
    for i in ast.literal_eval(text):
        #for crew data we need only director so we will break the loop once we get the director
        cnt += 1
        if parameter == 'job':
            if i['job'] == 'Director':
                L.append(i['name'])
                break
        else:
            L.append(i[f'{parameter}'])
            #for cast data we will take only first three characters
            if cnt == 3 and parameter == 'character':
                break


    return L

# %%
movies['genres'] = movies['genres'].apply(convert, args={'name'})

# %%
movies['keywords'] = movies['keywords'].apply(convert, args = {'name'})

# %%
movies['crew'] = movies['crew'].apply(convert, args = {'job'})

# %%
movies['cast'] = movies['cast'].apply(convert, args = {'character'})

# %%
# movies['overview']  = movies['overview'].apply(lambda x: x.split())
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
movies.sample(5)
# Out:
#       movie_id                        title  \
# 1335     23742                      Cop Out
# 891       1850              Man on the Moon
# 2363     68924                The Ice Storm
# 4745     90414  I Love You, Don't Touch Me!
# 2590    157849            A Most Wanted Man
#
#                                                overview  \
# 1335  [Detectives, Jimmy, and, Paul,, despite, nine,...
# 891   [A, film, about, the, life, and, career, of, t...
# 2363  [In, the, weekend, after, thanksgiving, 1973, ...
# 4745  [The, story, of, a, 25, year, old, virgin, gir...
# 2590  [When, a, half-Chechen,, half-Russian,, tortur...
#
#                         genres  \
# 1335   [Action, Comedy, Crime]
# 891   [Comedy, Drama, Romance]
# 2363                   [Drama]
# 4745         [Comedy, Romance]
# 2590                [Thriller]
#
#                                                keywords  \
# 1335  [new york, money laundering, daughter, police,...
# 891                [show business, comedian, wrestling]
# 2363  [based on novel, 1970s, thanksgiving, dysfunct...
# 4745                                   [woman director]
# 2590  [terror, muslim, intelligence, immigrant, tort...
#
#                                                    cast             crew
# 1335                  [Jimmy Monroe, Paul Hodges, Raul]    [Kevin Smith]
# 891   [Andy Kaufman/Tony Clifton, Lynne Margulies, J...   [Miloš Forman]
# 2363               [Ben Hood, Elena Hood, Janey Carver]        [Ang Lee]
# 4745                       [Katie, Ben, Richard Webber]    [Julie Davis]
# 2590  [Günther Bachmann, Annabel Richter, Martha Sul...  [Anton Corbijn]

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ","") for i in x])
movies.sample(5)
# Out:
#       movie_id                    title  \
# 3949     11229                  Freeway
# 3824     34769                 Defendor
# 2261     29078  The Game of Their Lives
# 4639    300327              Death Calls
# 1562      6557               27 Dresses
#
#                                                overview  \
# 3949  [Following, the, arrest, of, her, mother,, Ram...
# 3824  [A, crooked, cop,, a, mob, boss, and, the, you...
# 2261  [Based, on, a, true, story,, this, film, tells...
# 4639  [An, action-packed, love, story, on, the, Mexi...
# 1562  [Altruistic, Jane, finds, herself, facing, her...
#
#                               genres  \
# 3949       [Comedy, Drama, Thriller]
# 3824  [Drama, Action, Comedy, Crime]
# 2261                         [Drama]
# 4639                              []
# 1562               [Comedy, Romance]
#
#                                                keywords  \
# 3949  [prison, attempttoescape, stepfather, independ...
# 3824                [crimefighter, delusion, superhero]
# 2261                                            [sport]
# 4639                                                 []
# 1562  [lovesickness, newspaper, bar, sistersisterrel...
#
#                                                  cast              crew
# 3949  [BobWolverton, VanessaLutz, DetectiveMikeBreer]   [MatthewBright]
# 3824    [ArthurPoppington/Defendor, Kat, ChuckDooney]  [PeterStebbings]
# 2261      [FrankBorghi, WalterBahr, StanleyMortensen]   [DavidAnspaugh]
# 4639                                               []                []
# 1562           [JaneNichols, KevinDoyle, TessNichols]    [AnneFletcher]

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                                 cast                crew  \
# 0            [JakeSully, Neytiri, Dr.GraceAugustine]      [JamesCameron]
# 1   [CaptainJackSparrow, WillTurner, ElizabethSwann]     [GoreVerbinski]
# 2                    [JamesBond, Blofeld, Madeleine]         [SamMendes]
# 3  [BruceWayne/Batman, AlfredPennyworth, JamesGor...  [ChristopherNolan]
# 4                    [JohnCarter, DejahThoris, Sola]     [AndrewStanton]
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new_df = movies[['movie_id','title','tags']]

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
# Out:
# /tmp/ipykernel_6971/1824047427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# /tmp/ipykernel_6971/3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.sample(5)
# Out:
#       movie_id                  title  \
# 319       9890     The Stepford Wives
# 1736     17834          A Simple Wish
# 272      24113         Town & Country
# 1187     19912  The Final Destination
# 3617     13193                 Saved!
#
#                                                    tags
# 319   what does it take to become a stepford wife, a...
# 1736  murray is a male fairy godmother, and he is tr...
# 272   porter stoddard is a well-known new york archi...
# 1187  after a young man's premonition of a deadly ra...
# 3617  teenage mary cummings, who has "been born agai...

# %%
# Out:
# str
